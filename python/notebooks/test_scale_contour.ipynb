# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((512,512), np.uint8)

# %%
def draw_img(img, cmap='gray', dpi=100):
    
    height, width = img.shape[:2]

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(img, cmap=cmap)

    plt.show()

# %%
img_path = 'C:/Users/wt/Desktop/11-10/picture_553_2023_11_09_18_25_41_783.jpg'

# %%
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# %%
threshold, binary = cv2.threshold(img, 255, 255, cv2.THRESH_OTSU)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
closed = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

# %%
draw_img(binary)

# %%
draw_img(closed)

# %%
contours, hierarchy = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
contours[0].shape
# Out:
# (4130, 1, 2)

# %%
cv2.pointPolygonTest(contours[0], (2560, 1280), False)
# Out:
# 1.0
